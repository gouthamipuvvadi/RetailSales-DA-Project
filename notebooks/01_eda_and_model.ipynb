# %% [markdown]
# # EDA & Modeling Walkthrough\nRun this top-to-bottom to reproduce the analysis in a notebook.

# %%
from src.data_prep import load_and_clean\nfrom src.eda import run_eda\nfrom src.segmentation import run_rfm\nfrom src.model import run_model\ndf = load_and_clean()\nrun_eda(df)\nrun_rfm(df)\nrun_model(df)\nprint('Done.')
